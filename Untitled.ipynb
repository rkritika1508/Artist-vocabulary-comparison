# %%
import pandas as pd

# %%
data = pd.read_csv('SongLyrics4000.csv')
data1 = pd.read_csv('Lyrics1.csv')
data2 = pd.read_csv('Lyrics2.csv')
data3 = pd.read_csv('Lyrics3.csv')
data4 = pd.read_csv('Lyrics4.csv')
data5 = pd.read_csv('Lyrics5.csv')
data6 = pd.read_csv('Lyrics6.csv')
data7 = pd.read_csv('Lyrics7.csv')
data8 = pd.read_csv('Lyrics8.csv')
data9 = pd.read_csv('Lyrics9.csv')
data10 = pd.read_csv('Lyrics10.csv')
data11 = pd.read_csv('Lyrics11.csv')
data12 = pd.read_csv('Lyrics12.csv')
data13 = pd.read_csv('Lyrics13.csv')
data14 = pd.read_csv('Lyrics14.csv')
data15 = pd.read_csv('Lyrics15.csv')
data16 = pd.read_csv('Lyrics16.csv')
full_data = [data, data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14,
             data15, data16]

# %%
result = pd.concat(full_data)
result
# Out:
#                                                 Lyrics  \
# 0                                                  NaN
# 1    \r\r\r\r\r\n\r\r\r\r\r\r\nBaby, please stop me...
# 2                                                  NaN
# 3    \r\r\r\r\r\n\r\r\r\r\r\r\nHey have you heard t...
# 4                                                  NaN
# 5    \r\r\r\r\r\n\r\r\r\r\r\r\nI was a city boy\r\r...
# 6                                                  NaN
# 7    \r\r\r\r\r\n\r\r\r\r\r\r\nYou hear them people...
# 8                                                  NaN
# 9    \r\r\r\r\r\n\r\r\r\r\r\r\ni sold my soul for a...
# 10                                                 NaN
# 11   \r\r\r\r\r\n\r\r\r\r\r\r\nSweet emotion [2x]\r...
# 12                                                 NaN
# 13   \r\r\r\r\r\n\r\r\r\r\r\r\nGod I love the sweet...
# 14                                                 NaN
# 15   \r\r\r\r\r\n\r\r\r\r\r\r\nI think it's time to...
# ...

# %%
result.to_csv('SongLyrics4000.csv')
